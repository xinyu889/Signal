# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np
import math

import warnings
warnings.filterwarnings('ignore')

from IPython.html.widgets import interact, interact_manual, fixed
from IPython.html import widgets
from IPython.display import display

PI2 = 2 * math.pi

# %%
class xinyu_Sawtooth(thinkdsp.Sinusoid):
    
    
    def evaluate(self, ts):
        
        cycles = self.freq * ts + self.offset / PI2
        frac, _ = np.modf(cycles)
        ys = thinkdsp.normalize(thinkdsp.unbias(frac), self.amp)
        return ys

# %%
sawtooth = xinyu_Sawtooth().make_wave(duration=0.5, framerate=40000)
sawtooth.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sawtooth.make_spectrum().plot()

# %%
sawtooth.make_spectrum().plot(color='gray')
square = thinkdsp.SquareSignal(amp=0.5).make_wave(duration=0.5, framerate=40000)
square.make_spectrum().plot()

# %%
sawtooth.make_spectrum().plot(color='red')
triangle = thinkdsp.TriangleSignal(amp=0.79).make_wave(duration=0.5, framerate=40000)
triangle.make_spectrum().plot()

# %%
signal = thinkdsp.SinSignal(freq=1000, amp=10)
signal.plot()

# %%
sawtooth.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = sawtooth.make_spectrum()
spectrum.plot(high=2000)
